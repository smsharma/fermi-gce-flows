# %%
import numpy as np
import healpy as hp
import matplotlib.pyplot as plt

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("../")

# %%
import torch
from torch import nn

from models.embedding import SphericalGraphCNN

# %%
nside_list = [128, 64, 32, 16, 8, 4, 2]

# %%
sys.path.append("../../fermi-gce-gp/")
from utils import create_mask as cm

hp_mask_nside1 = cm.make_mask_total(nside=1, band_mask = True, band_mask_range = 0,
                              mask_ring = True, inner = 0, outer = 25)

indexes_list = []
masks_list = []
for nside in nside_list:
    hp_mask = hp.ud_grade(hp_mask_nside1, nside)
    masks_list.append(hp_mask)
    indexes_list.append(np.arange(hp.nside2npix(nside))[~hp_mask])

# %%
ps_mask = np.load("../../fermi-gce-gp/data/mask_3fgl_0p8deg.npy")
hp_mask = cm.make_mask_total(nside=128, band_mask = True, band_mask_range = 0,
                              mask_ring = True, inner = 0, outer = 25, custom_mask=ps_mask)
hp_mask

# %%
in_map = np.load("../../fermi-gce-gp/data/fermi_data/fermidata_counts.npy")
in_map[hp_mask] = 0

hp.mollview(in_map, max=100)

in_map = torch.Tensor(in_map[~masks_list[0]])
in_map = in_map.reshape((1, -1, 1))
in_map.shape

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Assuming that we are on a CUDA machine, this should print a CUDA device:

print(device)
# Out:
# cuda:0

# %%
sg = SphericalGraphCNN(nside_list, indexes_list).to(device)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-af9ad9cc2d0c> in <module>
# ----> 1 sg = SphericalGraphCNN(nside_list, indexes_list).to(device)
#
# ~/sbi-fermi/models/embedding.py in __init__(self, nside_list, indexes_list, kernel_size, laplacian_type)
#      26
#      27         self.laps = get_healpix_laplacians(nside_list=nside_list, laplacian_type=laplacian_type, indexes_list=indexes_list)
# ---> 28         self.register_buffer(self.laps)
#      29         self.cnn_layers = []
#      30
#
# TypeError: register_buffer() missing 1 required positional argument: 'tensor'

# %%
in_map.shape
# Out:
# torch.Size([1, 16384, 1])

# %%
in_map = in_map.to(device)

# %%
sg(in_map).shape
# Out:
# torch.Size([1, 64])

# %%
temp_gce = np.load("../data/fermi_data/template_gce.npy")

# %%
from models.scd import dnds
from utils.psf_correction import PSFCorrection
from utils.utils import make_dirs
from models.psf import KingPSF

# %%
kp = KingPSF()

pc_inst = PSFCorrection(delay_compute=True)
pc_inst.psf_r_func = lambda r: kp.psf_fermi_r(r)

# %%
from simulations.simulate_ps import SimulateMap

# %%
from sbi import utils
from sbi import inference
from sbi.inference.base import infer

# %%
in_map.shape
# Out:
# torch.Size([1, 16384, 1])

# %%
def simulator_model(parameter):
    s_ary = torch.logspace(-1, 2, 100)
    dnds_ary = dnds(s_ary, torch.tensor(parameter)).numpy()
    sm = SimulateMap([],[],[s_ary],[dnds_ary], [temp_gce], pc_inst.psf_r_func, n_exp=[parameter[0]])
    the_map = np.array(sm.create_map()).astype(np.float32)
    the_map /= np.mean(the_map)
    the_map = the_map.reshape((1, -1))[:, ~masks_list[0]]
    return the_map

# %%
parameter = [1000, 10., 1.9, -10., 20., 0.1]
simulator_model(parameter)
# Out:
# array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32)

# %%
from tqdm import *

# %%
number_presimulated = 10

prior = utils.BoxUniform(low=torch.tensor([0., 10., 1.1, -10., 5., 0.1]), 
                         high=torch.tensor([1000., 20., 1.9, 1.9, 50., 4.99]))

theta_presimulated = prior.sample((number_presimulated,))

x_presimulated = [simulator_model(theta) for theta in tqdm(theta_presimulated)]
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]<ipython-input-55-b8a429a3608f>:3: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   dnds_ary = dnds(s_ary, torch.tensor(parameter)).numpy()
# 100%|██████████| 10/10 [00:05<00:00,  1.77it/s]

# %%
# from sbi.simulators import simulate_in_batches

# simulate_in_batches(
#         simulator_model, theta_presimulated, num_workers=1, show_progress_bars=True)

# %%
theta_presimulated = torch.Tensor(theta_presimulated)
x_presimulated = torch.Tensor(x_presimulated)

# %%
from torch.utils.tensorboard import SummaryWriter

writer = SummaryWriter()

# %%
# set prior distribution for the parameters 
prior = utils.BoxUniform(low=torch.tensor([0., 10., 1.1, -10., 5., 0.1]), 
                         high=torch.tensor([1000., 20., 1.9, 1.9, 50., 4.99]))

# make a SBI-wrapper on the simulator object for compatibility
simulator_wrapper, prior = inference.prepare_for_sbi(simulator_model, prior)

# # instantiate the neural density estimator
# neural_classifier = utils.classifier_nn(model='linear',
#                                       embedding_net_x=sg)

# # setup the inference procedure with the SNPE-C procedure
# inference_inst = inference.SNRE_A(simulator_wrapper, prior,
#                            classifier=neural_classifier, 
#                            show_progress_bars=True, show_round_summary=True, 
#                            logging_level='INFO',
#                            summary_writer=writer,
#                            mcmc_method='hmc')

# instantiate the neural density estimator
neural_classifier = utils.posterior_nn(model='maf',
                                      embedding_net=sg,
                                      hidden_features=40,
                                      num_transforms=4,
)

# setup the inference procedure with the SNPE-C procedure
inference_inst = inference.SNPE_C(simulator_wrapper, prior,
                           density_estimator=neural_classifier, 
                           show_progress_bars=True, show_round_summary=True, 
                           logging_level='INFO',
#                            summary_writer=writer,
                                 sample_with_mcmc=True,
                                 mcmc_method="slice_np")
# Out:
# <ipython-input-55-b8a429a3608f>:3: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   dnds_ary = dnds(s_ary, torch.tensor(parameter)).numpy()

# %%
inference_inst.provide_presimulated(theta_presimulated, x_presimulated[:, 0, :])

# %%
sg
# Out:
# SphericalGraphCNN(
#   (layer_0): SphericalChebBNPool(
#     (spherical_cheb): SphericalChebConv(
#       (chebconv): ChebConv()
#     )
#     (pooling): HealpixMaxPool(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#     (batchnorm): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (layer_1): SphericalChebBNPool(
#     (spherical_cheb): SphericalChebConv(
#       (chebconv): ChebConv()
#     )
#     (pooling): HealpixMaxPool(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#     (batchnorm): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (layer_2): SphericalChebBNPool(
#     (spherical_cheb): SphericalChebConv(
#       (chebconv): ChebConv()
#     )
#     (pooling): HealpixMaxPool(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#     (batchnorm): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (layer_3): SphericalChebBNPool(
#     (spherical_cheb): SphericalChebConv(
#       (chebconv): ChebConv()
#     )
#     (pooling): HealpixMaxPool(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#     (batchnorm): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (layer_4): SphericalChebBNPool(
#     (spherical_cheb): SphericalChebConv(
#       (chebconv): ChebConv()
#     )
#     (pooling): HealpixMaxPool(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#     (batchnorm): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (layer_5): SphericalChebBNPool(
#     (spherical_cheb): SphericalChebConv(
#       (chebconv): ChebConv()
#     )
#     (pooling): HealpixMaxPool(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#     (batchnorm): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (layer_6): SphericalChebBNPool(
#     (spherical_cheb): SphericalChebConv(
#       (chebconv): ChebConv()
#     )
#     (pooling): HealpixMaxPool(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#     (batchnorm): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (fc1): Linear(in_features=256, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=64, bias=True)
# )

# %%
# run the inference procedure on one round and 10000 simulated data points
posterior = inference_inst(num_simulations=0, training_batch_size=32, max_num_epochs=200)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-65-583508ff325d> in <module>
#       1 # run the inference procedure on one round and 10000 simulated data points
# ----> 2 posterior = inference_inst(num_simulations=0, training_batch_size=32, max_num_epochs=200)
#
# ~/anaconda3/lib/python3.8/site-packages/sbi-0.13.2-py3.8.egg/sbi/inference/snpe/snpe_c.py in __call__(self, num_simulations, proposal, num_atoms, training_batch_size, learning_rate, validation_fraction, stop_after_epochs, max_num_epochs, clip_max_norm, calibration_kernel, exclude_invalid_x, discard_prior_samples, retrain_from_scratch_each_round)
#     209                 self._set_state_for_mog_proposal()
#     210
# --> 211         return super().__call__(**kwargs)
#     212
#     213     def _set_state_for_mog_proposal(self) -> None:
#
# ~/anaconda3/lib/python3.8/site-packages/sbi-0.13.2-py3.8.egg/sbi/inference/snpe/snpe_base.py in __call__(self, num_simulations, proposal, training_batch_size, learning_rate, validation_fraction, stop_after_epochs, max_num_epochs, clip_max_norm, calibration_kernel, exclude_invalid_x, discard_prior_samples, retrain_from_scratch_each_round)
#     191             self._posterior = DirectPosterior(
#     192                 method_family="snpe",
# --> 193                 neural_net=self._build_neural_net(theta, x),
#     194                 prior=self._prior,
#     195                 x_shape=x_shape,
#
# ~/anaconda3/lib/python3.8/site-packages/sbi-0.13.2-py3.8.egg/sbi/utils/get_nn_models.py in build_fn(batch_theta, batch_x)
#     207             return build_made(batch_x=batch_theta, batch_y=batch_x, **kwargs)
#     208         if model == "maf":
# --> 209             return build_maf(batch_x=batch_theta, batch_y=batch_x, **kwargs)
#     210         elif model == "nsf":
#     211             return build_nsf(batch_x=batch_theta, batch_y=batch_x, **kwargs)
#
# ~/anaconda3/lib/python3.8/site-packages/sbi-0.13.2-py3.8.egg/sbi/neural_nets/flow.py in build_maf(batch_x, batch_y, z_score_x, z_score_y, hidden_features, num_transforms, embedding_net, **kwargs)
#     103     x_numel = batch_x[0].numel()
#     104     # Infer the output dimensionality of the embedding_net by making a forward pass.
# --> 105     y_numel = embedding_net(batch_y[:1]).numel()
#     106
#     107     if x_numel == 1:
#
# ~/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# ~/sbi-fermi/models/embedding.py in forward(self, x)
#      49
#      50         for layer in self.cnn_layers:
# ---> 51             x = layer(x)
#      52
#      53         x = F.relu(self.fc1(x))
#
# ~/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# ~/sbi-fermi/models/layers.py in forward(self, x)
#      36             :obj:`torch.tensor`: output [batch x vertices x channels/features]
#      37         """
# ---> 38         x = self.spherical_cheb(x)
#      39         x = self.batchnorm(x.permute(0, 2, 1))
#      40         x = F.relu(x.permute(0, 2, 1))
#
# ~/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# ~/sbi-fermi/models/chebyshev.py in forward(self, x)
#     150             :obj:`torch.tensor`: output [batch x vertices x channels/features]
#     151         """
# --> 152         x = self.chebconv(self.laplacian, x)
#     153         return x
#
# ~/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# ~/sbi-fermi/models/chebyshev.py in forward(self, laplacian, inputs)
#     103             :obj:`torch.Tensor`: The convoluted inputs.
#     104         """
# --> 105         outputs = self._conv(laplacian, inputs, self.weight)
#     106         if self.bias is not None:
#     107             outputs += self.bias
#
# ~/sbi-fermi/models/chebyshev.py in cheb_conv(laplacian, inputs, weight)
#      34
#      35     if K > 0:
# ---> 36         x1 = torch.sparse.mm(laplacian, x0)  # V x Fin*B
#      37         inputs = torch.cat((inputs, x1.unsqueeze(0)), 0)  # 2 x V x Fin*B
#      38         for _ in range(1, K - 1):
#
# ~/anaconda3/lib/python3.8/site-packages/torch/sparse/__init__.py in mm(mat1, mat2)
#      81                size=(2, 3), nnz=6, layout=torch.sparse_coo)
#      82     """
# ---> 83     return torch._sparse_mm(mat1, mat2)
#      84
#      85
#
# RuntimeError: addmm: expected 'self' to be CUDA, but got CPU

# %%
# generate posterior samples
true_parameter = torch.tensor([300, 10., 1.9, -10., 20., 0.1])
x_observed = simulator_model(true_parameter)
samples = posterior.set_default_x(x_observed).sample((100,))
# Out:
# /Users/smsharma/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   This is separate from the ipykernel package so we can avoid doing imports until
# Warmup:   0%|          | 4/1021 [04:31, 80.13s/it, step size=2.67e-04, acc. prob=0.000]
# KeyboardInterrupt

# %%
# create the figure
fig, ax = utils.pairplot(samples, 
                             points=true_parameter,
#                              labels=['r', r'$\theta$'], 
#                              limits=[[0, 600], [-2, 0]],
                             points_colors='r',
                             points_offdiag={'markersize': 6},
                             fig_size=[7.5, 6.4])
